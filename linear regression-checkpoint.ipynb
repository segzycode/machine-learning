# %% [markdown]
# # LINEAR REGRSSION

# %%
import pandas as pd 
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
data = pd.read_csv("household.csv")

# %%
data.head()
# Out:
#         hlpi_name  year   hlpi nzhec               nzhec_name   nzhec_short  \
# 0  All households  2008  allhh     1                     Food          Food
# 1  All households  2008  allhh   1.1     Fruit and vegetables   Fruit & veg
# 2  All households  2008  allhh   1.2   Meat, poultry and fish          Meat
# 3  All households  2008  allhh   1.3             Grocery food  Grocery food
# 4  All households  2008  allhh   1.4  Non-alcoholic beverages   Soft drinks
#
#       level  nzhec1 nzhec1_name nzhec1_short  weight  exp_pw  eqv_exp_pw
# 0     group       1        Food         Food    18.0   146.3        86.7
# 1  subgroup       1        Food         Food     2.6    21.3        12.6
# 2  subgroup       1        Food         Food     3.1    25.6        15.2
# 3  subgroup       1        Food         Food     7.4    59.9        35.5
# 4  subgroup       1        Food         Food     1.7    14.0         8.3

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3360 entries, 0 to 3359
# Data columns (total 13 columns):
# hlpi_name       3360 non-null object
# year            3360 non-null int64
# hlpi            3360 non-null object
# nzhec           3360 non-null object
# nzhec_name      3360 non-null object
# nzhec_short     3360 non-null object
# level           3360 non-null object
# nzhec1          3360 non-null int64
# nzhec1_name     3360 non-null object
# nzhec1_short    3360 non-null object
# weight          3360 non-null float64
# exp_pw          3360 non-null float64
# eqv_exp_pw      3360 non-null float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 341.3+ KB

# %%
data.describe()
# Out:
#               year       nzhec1       weight       exp_pw   eqv_exp_pw
# count  3360.000000  3360.000000  3360.000000  3360.000000  3360.000000
# mean   2012.500000     6.400000     3.750893    33.569732    20.176220
# std       3.354601     3.333163     4.812609    44.802895    26.485688
# min    2008.000000     1.000000     0.000000     0.000000     0.000000
# 25%    2010.250000     4.000000     0.700000     5.500000     3.400000
# 50%    2012.500000     6.000000     2.300000    18.100000    11.000000
# 75%    2014.750000     9.000000     4.625000    41.400000    25.300000
# max    2017.000000    13.000000    43.500000   367.200000   214.700000

# %%
data.columns
# Out:
# Index(['hlpi_name', 'year', 'hlpi', 'nzhec', 'nzhec_name', 'nzhec_short',
#        'level', 'nzhec1', 'nzhec1_name', 'nzhec1_short', 'weight', 'exp_pw',
#        'eqv_exp_pw'],
#       dtype='object')

# %%
sns.pairplot(data)

# %%
sns.distplot(data['exp_pw'])
# Out:
# C:\acaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
data.corr()
# Out:
#                     year        nzhec1    weight    exp_pw  eqv_exp_pw
# year        1.000000e+00  4.493103e-19  0.004177  0.075121    0.072427
# nzhec1      4.493103e-19  1.000000e+00 -0.226031 -0.180390   -0.185904
# weight      4.176733e-03 -2.260311e-01  1.000000  0.842662    0.862068
# exp_pw      7.512097e-02 -1.803901e-01  0.842662  1.000000    0.996338
# eqv_exp_pw  7.242727e-02 -1.859036e-01  0.862068  0.996338    1.000000

# %%
sns.heatmap (data.corr(), annot=True)

# %%
data.columns
# Out:
# Index(['hlpi_name', 'year', 'hlpi', 'nzhec', 'nzhec_name', 'nzhec_short',
#        'level', 'nzhec1', 'nzhec1_name', 'nzhec1_short', 'weight', 'exp_pw',
#        'eqv_exp_pw'],
#       dtype='object')
